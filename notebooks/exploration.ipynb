# %%
from models import models 
from utils import gen_mlflow_metrics, param1
from dataset import df, X_train, X_test, X_val, y_train, y_test, y_val

exp1 = models(param1)
exp1.Val_reports()
# Out:
# RandomForest:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.92      0.96        13
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
#
# DecisionTree:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.85      0.92        13
#            2       0.80      1.00      0.89         8
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.95      0.94        30
# weighted avg       0.95      0.93      0.93        30
#
#
# Default_DecisionTree:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
# ...
